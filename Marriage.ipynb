# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from sqlalchemy import create_engine, types
from sqlalchemy import text # to be able to pass string

# %%
df= pd.read_csv('World_Marriage_Dataset.csv')

# %%
df.sample(10)
# Out:
#         Sr.No.         Country AgeGroup    Sex  \
# 105118  105119         Hungary  [20-24]  Woman
# 102940  102941        Honduras  [55-59]  Woman
# 224549  224550        Slovenia  [10-14]  Woman
# 5735      5736           Aruba  [35-39]  Woman
# 1027      1028         Albania  [40-44]  Woman
# 234801  234802          Sweden  [55-59]  Woman
# 208707  208708           Samoa  [15-19]    Man
# 170229  170230     Netherlands  [10-14]  Woman
# 159841  159842          Mexico  [20-24]    Man
# 2247      2248  American Samoa  [25-29]  Woman
#
#                            MaritalStatus DataProcess  \
# 105118                           Widowed    Estimate
# 102940                           Widowed      Census
# 224549                          Divorced    Estimate
# 5735                             Married      Census
# 1027                             Married      Survey
# 234801                           Married    Estimate
# 208707                         Separated      Census
# 170229  Married or married but separated    Estimate
# 159841                           Widowed      Survey
# 2247                             Widowed      Census
#
#         Data Collection (Start Year)  Data Collection (End Year)  \
# 105118                          1984                        1984
# 102940                          1988                        1988
# 224549                          2015                        2015
# 5735                            2000                        2000
# 1027                            2008                        2009
# 234801                          1988                        1988
# 208707                          1976                        1976
# 170229                          1980                        1980
# 159841                          2015                        2015
# 2247                            1974                        1974
#
#                 Data Source
# 105118                 UNSD
# 102940     US Census Bureau
# 224549                 UNSD
# 5735                   UNSD
# 1027                 DHS_HH
# 234801                 UNSD
# 208707                 UNSD
# 170229                 UNSD
# 159841  National statistics
# 2247                   UNSD

# %%
df.drop(columns=["Sr.No."], inplace=True)

# %%
df
# Out:
#             Country AgeGroup    Sex MaritalStatus DataProcess  \
# 0       Afghanistan  [15-19]    Man      Divorced      Survey
# 1       Afghanistan  [20-24]    Man      Divorced      Survey
# 2       Afghanistan  [25-29]    Man      Divorced      Survey
# 3       Afghanistan  [30-34]    Man      Divorced      Survey
# 4       Afghanistan  [35-39]    Man      Divorced      Survey
# ...             ...      ...    ...           ...         ...
# 271599     Zimbabwe  [55-59]  Woman       Widowed      Survey
# 271600     Zimbabwe  [60-64]  Woman       Widowed      Survey
# 271601     Zimbabwe  [65-69]  Woman       Widowed      Survey
# 271602     Zimbabwe  [70-74]  Woman       Widowed      Survey
# 271603     Zimbabwe    [75+]  Woman       Widowed      Survey
#
#         Data Collection (Start Year)  Data Collection (End Year)  \
# 0                               1972                        1974
# 1                               1972                        1974
# 2                               1972                        1974
# 3                               1972                        1974
# 4                               1972                        1974
# ...                              ...                         ...
# 271599                          2017                        2017
# 271600                          2017                        2017
# 271601                          2017                        2017
# 271602                          2017                        2017
# 271603                          2017                        2017
#
#                 Data Source
# 0       National statistics
# 1       National statistics
# 2       National statistics
# 3       National statistics
# 4       National statistics
# ...                     ...
# 271599  National statistics
# 271600  National statistics
# 271601  National statistics
# 271602  National statistics
# 271603  National statistics
#
# [271604 rows x 8 columns]

# %%
df.columns = df.columns.str.lower() \
    .str.replace(' ', '_') \
    .str.replace('(', '') \
    .str.replace(')', '') \
    .str.replace('[^0-9a-zA-Z_]', '', regex=True)

# %%
df.rename(columns={
    "agegroup": "age_group",
    "maritalstatus": "marital_status",
    "dataprocess": "data_process",
    "Data Collection (Start Year)": "data_collection_start_year",
    "Data Collection (End Year)": "data_collection_end_year",
    "Data Source": "data_source",
    "Country": "country",
    "Sex": "sex"
}, inplace=True)

# %%
df.sample(5)
# Out:
#                                    country age_group    sex  \
# 79091                              Finland   [35-39]  Woman
# 265163  Venezuela (Bolivarian Republic of)   [45-49]    Man
# 4405                               Armenia   [16-19]  Woman
# 226971                        South Africa   [60-64]  Woman
# 52279                        Côte d'Ivoire   [70-74]    Man
#
#                marital_status data_process  data_collection_start_year  \
# 79091                Divorced     Estimate                        2004
# 265163               Divorced       Census                        2011
# 4405    Divorced or Separated       Census                        1979
# 226971                Widowed       Survey                        2016
# 52279                 Widowed       Census                        1998
#
#         data_collection_end_year          data_source
# 79091                       2004                 UNSD
# 265163                      2011                 UNSD
# 4405                        1979  National statistics
# 226971                      2016               DHS_HH
# 52279                       1998                 INED

# %%
df.drop_duplicates(inplace=True)
print(df.isnull().sum())
# Out:
# country                       0
# age_group                     0
# sex                           0
# marital_status                0
# data_process                  0
# data_collection_start_year    0
# data_collection_end_year      0
# data_source                   0
# dtype: int64

# %%
print(df.head())
# Out:
#        country age_group  sex marital_status data_process  \
# 0  Afghanistan   [15-19]  Man       Divorced       Survey
# 1  Afghanistan   [20-24]  Man       Divorced       Survey
# 2  Afghanistan   [25-29]  Man       Divorced       Survey
# 3  Afghanistan   [30-34]  Man       Divorced       Survey
# 4  Afghanistan   [35-39]  Man       Divorced       Survey
#
#    data_collection_start_year  data_collection_end_year          data_source
# 0                        1972                      1974  National statistics
# 1                        1972                      1974  National statistics
# 2                        1972                      1974  National statistics
# 3                        1972                      1974  National statistics
# 4                        1972                      1974  National statistics

# %%
df.to_csv("cleaned_world_marriage.csv", index=False)
